# %% [markdown]
# Adinda Wahyu Luchmansyahvira
# TI-3H / 2141720096

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
img_4 = cv.imread('/content/KTP.jpeg.jpg')
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB)
cv2_imshow(img_4)
plt.imshow(img_5)
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>

# %%
img_4s = np.copy(img_4)
#tutup bagian foto
for y in range (570,780):
  for x in range (90,340):
    img_4s[x,y] = [0,0,0]

#tutup bagian golongan darah
img_4ss = np.copy(img_4s)
for y in range (390,550):
  for x in range (165,185):
    img_4ss[x,y] = [0,255,255]
final_frame = cv.hconcat((img_4, img_4ss))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x488>
